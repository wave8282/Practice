# %%
'-'.join('2000.8.10'.split('.'))
# Out:
# '2000-8-10'

# %%
','.join(['apple', 'banana', 'grape'])
# Out:
# 'apple,banana,grape'

# %%
s = 'sdqwqd ds dsagqeesa'
list(s)
# Out:
# ['s',
#  'd',
#  'q',
#  'w',
#  'q',
#  'd',
#  ' ',
#  'd',
#  's',
#  ' ',
#  'd',
#  's',
#  'a',
#  'g',
#  'q',
#  'e',
#  'e',
#  's',
#  'a']

# %%
''.join(s)
# Out:
# 'sdqwqd ds dsagqeesa'

# %%
import string

string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
 s = 'sdakh dlkq wnkw fqjfqp eojg fnkd fask djsal kfa;skdpwq fsafjl;safsla d qkwdfas'

length = len(s.split(' '))
print(length)
# Out:
# 12

# %%
pip install wikipedia wordcloud
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=a44230ebd6f9d57e98aefb4fb580a89d69a28cd2d38c0783f734832861f23cb6
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %%
import wikipedia

# %%
wiki = wikipedia,page('Artificial intelligence')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6fafc4e62a96> in <cell line: 1>()
# ----> 1 wiki = wikipedia,page('Artificial intelligence')
#
# NameError: name 'page' is not defined

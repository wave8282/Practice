# %%
A = []
A.insert(0, 10)
A
# Out:
# [10]

# %%
A.insert(1, 20)
A.insert(0, 30)
A.insert(2, 40)
A
# Out:
# [30, 10, 40, 20]

# %%
A.insert(size(), 50)
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1f43e4803680> in <cell line: 1>()
# ----> 1 A.insert(size(), 50)
#       2 A
#
# NameError: name 'size' is not defined

# %%
A = [1,3,4]
B = [2,3,6,7]
C = A + B
C
# Out:
# [1, 3, 4, 2, 3, 6, 7]

# %%
A = list(map(int, input().split()))
B = list(map(int, input().split()))
C = A + B
print(sorted(C))
# Out:
# 1 3 4 2 5 6 7
# 9 8
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
A = list(map(int, input().split()))
